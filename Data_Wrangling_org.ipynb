# %% [markdown]
# <a href="https://colab.research.google.com/github/HANEENA001/my-new-repo/blob/main/Data_Wrangling_org.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <u> Use only those concepts which have been taught till now </u>

# %% [markdown]
# # <b><u> Problem 1: </u> Which actor has acted in the most number of movies? Deep dive into the movies, genres and profits corresponding to this actor. </b>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/colab works/imdb_data (1).csv')
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.head(10)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
# 7   8                                                NaN         0
# 8   9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 9  10                                                NaN   6000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# ...

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df['profit'] = df['revenue']-df['budget']
df['profit'].head()
# Out:
# 0    -1685349
# 1    55149435
# 2     9792000
# 3    14800000
# 4     3923970
# Name: profit, dtype: int64

# %%
def convert_list(string):
  return eval(string)

# %%
df.loc[~df['cast'].isna(),'cast'] = df.loc[~df['cast'].isna(),'cast'].apply(convert_list)

# %%
df.loc[~df['genres'].isna(),'genres'] = df.loc[~df['genres'].isna(),'genres'].apply(convert_list)

# %%
type(df['genres'][0])
# Out:
# list

# %%
df['cast']
df['cast_name'] = df['cast'].apply(lambda x:[i['name'] for i in x] if isinstance(x,list) else [])
df['cast_name']
# Out:
# 0       [Rob Corddry, Craig Robinson, Clark Duke, Adam...
# 1       [Anne Hathaway, Julie Andrews, Héctor Elizond...
# 2       [Miles Teller, J.K. Simmons, Melissa Benoist, ...
# 3       [Vidya Balan, Nawazuddin Siddiqui, Parambrata ...
# 4       [Kim Kang-woo, Jo Jae-hyeon, Park Si-yeon, Kim...
#                               ...
# 2995    [Tom Berenger, William McNamara, Эрика Э...
# 2996    [Mira Barkhammar, Mira Grosin, Liv LeMoyne, Da...
# 2997    [Geena Davis, Samuel L. Jackson, Yvonne Zima, ...
# 2998    [Ben Stiller, Jennifer Aniston, Philip Seymour...
# 2999    [Taylor Lautner, Lily Collins, Alfred Molina, ...
# Name: cast_name, Length: 3000, dtype: object

# %%
df['genres_list'] = df['genres'].apply(lambda x : [i['name'] for i in x] if isinstance(x,list) else[])

# %%
df.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ...    status  \
# 0      6.5754  ...  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue   profit  \
# ...

# %%
cast_expld = df.explode('cast_name')
cast_expld.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ...    status  \
# 0      6.5754  ...  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue   profit  \
# ...

# %%
act_mov = pd.DataFrame(cast_expld['cast_name'].value_counts()).reset_index()

print(type(act_mov))
act_mov.columns = ['actor','no_movs']
act_mov.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                actor  no_movs
# 0     Robert De Niro       30
# 1  Samuel L. Jackson       30
# 2     Morgan Freeman       27
# 3       Bruce Willis       25
# 4       J.K. Simmons       25
# 5        Liam Neeson       25
# 6     Susan Sarandon       25
# 7       Bruce McGill       24
# 8      John Turturro       24
# 9       Willem Dafoe       23

# %%
act_perf =  cast_expld.groupby('cast_name').agg({'genres_list':'sum','profit':'mean'}).reset_index()
act_perf.head(10)
# Out:
#              cast_name                                        genres_list  \
# 0     Larry Mullen Jr.                               [Music, Documentary]
# 1       Michael Hayden                                      [Documentary]
# 2  "Weird Al" Yankovic                                    [Comedy, Drama]
# 3  'Sister' Carol East                   [Action, Comedy, Drama, Romance]
# 4              50 Cent  [Action, Crime, Drama, Thriller, Drama, Thrill...
# 5           A Martinez                [Action, Adventure, Drama, Western]
# 6   A. C. Murali Mohan            [Action, Comedy, Drama, Drama, Foreign]
# 7    A. David Burleigh                            [Action, Comedy, Drama]
# 8        A. Glauberman                                   [Drama, History]
# 9         A. J. Langer  [Family, Science Fiction, Action, Adventure, S...
#
#           profit
# 0   7730842.0000
# 1    602042.0000
# 2    343786.0000
# 3   8362969.0000
# 4  29512716.8000
# 5   1500000.0000
# 6   4000000.0000
# ...

# %%
pd.options.display.float_format = '{:.4f}'.format
act_perf.loc[(act_perf['cast_name']=='Robert De Niro') | (act_perf['cast_name']=='Samuel L. Jackson') |  (act_perf['cast_name']=='Morgan Freeman') ].rename({'profit':'avg_profit'},axis=1).reset_index()
# Out:
#    index          cast_name  \
# 0  26518     Morgan Freeman
# 1  30927     Robert De Niro
# 2  32323  Samuel L. Jackson
#
#                                          genres_list     avg_profit
# 0  [Action, Drama, Science Fiction, Thriller, Dra...  77610244.4815
# 1  [Drama, Comedy, Drama, Comedy, Crime, Romance,...  30043750.9333
# 2  [Action, Adventure, Crime, Thriller, Crime, Dr... 226510055.6667

# %% [markdown]
# # <b><u> Problem 2 :</u> Top 3 directors prefer which actors the most?

# %%
pd.DataFrame(eval(df['crew'][0]))
# Out:
#                    credit_id         department  gender       id  \
# 0   59ac067c92514107af02c8c8          Directing       0  1449071
# 1   52fe4ee7c3a36847f82afad7          Directing       2     3227
# 2   5524ed25c3a3687ded000d88            Writing       2   347335
# 3   5524ed2d925141720c001128            Writing       2   347335
# 4   5524ed3d92514166c1004a5d         Production       2    57822
# ..                       ...                ...     ...      ...
# 67  59ac0e9f925141079d02bee6  Costume & Make-Up       0  1552626
# 68  59ac0ec1c3a3682bf0029524  Costume & Make-Up       0  1881605
# 69  59ac0eef925141070702c7ff  Costume & Make-Up       0  1463801
# 70  59ac0f5dc3a3682c4802a0f5         Production       0  1400837
# 71  59ac0ff2c3a3682c4802a196               Crew       0  1844322
#
#                          job              name  \
# 0   First Assistant Director     Kelly Cantley
# 1                   Director        Steve Pink
# ...

# %%
def Dname(crew):
  for i in range(len(aa)):
    print(i)
    if crew[i]['job']== 'Director':
      named =aa[i]['name']
    else:
      return np.nan

  return named

def find_directors(li):
  #print(li)
  job_iterator = 0

  if type(li)!= float:
    #li = eval(li)
    while True:
      if li[job_iterator]['job']!='Director':
        job_iterator+=1
      else:
        return li[job_iterator]['name']

# %%
df.loc[~df['crew'].isna(),'crew'] = df.loc[~df['crew'].isna(),'crew'].apply(convert_list)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
df['director_name'] = df['crew'].apply(find_directors)
df['director_name'].tail(15)
# Out:
# 2985            Joe Roth
# 2986        Paul Abascal
# 2987        Thierry Notz
# 2988    Abbas Kiarostami
# 2989        Richard Rich
# 2990     Robert Townsend
# 2991       Thomas Carter
# 2992         Raoul Walsh
# 2993    Steven Spielberg
# 2994       Robert Mandel
# 2995       Dennis Hopper
# 2996     Lukas Moodysson
# 2997        Renny Harlin
# 2998        John Hamburg
# 2999      John Singleton
# Name: director_name, dtype: object

# %%
direct_rank= df.groupby('director_name')['popularity'].mean().sort_values(ascending = False).reset_index()

print(direct_rank.head(4))
print(df.head(2))
# Out:
#   director_name  popularity
# 0    Tim Miller    187.8605
# 1    James Gunn    119.3113
# 2  Edgar Wright    118.9316
# 3   Bill Condon     81.2751
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
#
#                                               genres homepage    imdb_id  \
# 0                     [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  tt0368933
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...      6.5754  ...
# ...

# %%
actor1 = list(df[df['director_name']==direct_rank['director_name'][0]]['cast_name'])[0][0]
actor2 = list(df[df['director_name']==direct_rank['director_name'][1]]['cast_name'])[0][0]
actor3 = list(df[df['director_name']==direct_rank['director_name'][2]]['cast_name'])[0][0]

print(f"Top director {direct_rank['director_name'][0]}'s prefered actor is {actor1}")
print(f"Second Top director {direct_rank['director_name'][1]} prefered actor is {actor2}")
print(f"Third Top director {direct_rank['director_name'][2]} prefered actor is {actor3}")
# Out:
# Top director Tim Miller's prefered actor is Ryan Reynolds
# Second Top director James Gunn prefered actor is Chris Pratt
# Third Top director Edgar Wright prefered actor is Simon Pegg
